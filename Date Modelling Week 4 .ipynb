# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
import re
import seaborn as sns

# %%
r=pd.read_csv('newitems1.csv')

# %%
r.head()
# Out:
#    Unnamed: 0                          product_name  \
# 0           0     Redmi K20 Pro (Flame Red, 128 GB)
# 1           1              Mi Mix 2 (Black, 128 GB)
# 2           2  Redmi K20 Pro (Carbon Black, 128 GB)
# 3           3       Mi A3 (More Than White, 128 GB)
# 4           4         Mi A3 (Not just Blue, 128 GB)
#
#                                    product_processor product_price  \
# 0                  Qualcomm Snapdragon 855 Processor        26,999
# 1  Qualcomm Snapdragon 835 Octa Core 2.5 GHz Proc...        19,999
# 2                  Qualcomm Snapdragon 855 Processor        26,999
# 3                  Qualcomm Snapdragon 665 Processor        14,999
# 4                  Qualcomm Snapdragon 665 Processor        17,299
#
#    product_rating  Product_dimention in cm  Battery in mAh  Ram in GB  \
# 0             4.5                    16.23            4000          6
# 1             4.3                    15.21            3400          6
# ...

# %%
del r['Unnamed: 0']

# %%
r
# Out:
#                                product_name  \
# 0         Redmi K20 Pro (Flame Red, 128 GB)
# 1                  Mi Mix 2 (Black, 128 GB)
# 2      Redmi K20 Pro (Carbon Black, 128 GB)
# 3           Mi A3 (More Than White, 128 GB)
# 4             Mi A3 (Not just Blue, 128 GB)
# 5       Redmi K20 Pro (Pearl White, 128 GB)
# 6      Redmi K20 Pro (Glacier Blue, 128 GB)
# 7         Redmi K20 Pro (Flame Red, 256 GB)
# 8           Redmi K20 (Carbon Black, 64 GB)
# 9                       Mi A2 (Red, 128 GB)
# 10             Mi A3 (Kind of Grey, 128 GB)
# 11          Redmi Note 6 Pro (Black, 64 GB)
# 12     Redmi K20 Pro (Carbon Black, 256 GB)
# 13         Redmi K20 (Glacier Blue, 128 GB)
# 14            Redmi K20 (Flame Red, 128 GB)
# 15           Redmi Note 5 Pro (Gold, 64 GB)
# 16      Redmi K20 Pro (Pearl White, 256 GB)
# 17      Redmi Note 6 Pro (Rose Gold, 64 GB)
# 18         Redmi K20 (Carbon Black, 128 GB)
# 19      Redmi Note 6 Pro (Rose Gold, 64 GB)
# ...

# %%
r['product_price'] = r['product_price'].str.replace(',', '')
r
# Out:
#                                product_name  \
# 0         Redmi K20 Pro (Flame Red, 128 GB)
# 1                  Mi Mix 2 (Black, 128 GB)
# 2      Redmi K20 Pro (Carbon Black, 128 GB)
# 3           Mi A3 (More Than White, 128 GB)
# 4             Mi A3 (Not just Blue, 128 GB)
# 5       Redmi K20 Pro (Pearl White, 128 GB)
# 6      Redmi K20 Pro (Glacier Blue, 128 GB)
# 7         Redmi K20 Pro (Flame Red, 256 GB)
# 8           Redmi K20 (Carbon Black, 64 GB)
# 9                       Mi A2 (Red, 128 GB)
# 10             Mi A3 (Kind of Grey, 128 GB)
# 11          Redmi Note 6 Pro (Black, 64 GB)
# 12     Redmi K20 Pro (Carbon Black, 256 GB)
# 13         Redmi K20 (Glacier Blue, 128 GB)
# 14            Redmi K20 (Flame Red, 128 GB)
# 15           Redmi Note 5 Pro (Gold, 64 GB)
# 16      Redmi K20 Pro (Pearl White, 256 GB)
# 17      Redmi Note 6 Pro (Rose Gold, 64 GB)
# 18         Redmi K20 (Carbon Black, 128 GB)
# 19      Redmi Note 6 Pro (Rose Gold, 64 GB)
# ...

# %%
r.to_csv("newitems16.csv")

# %%
h=pd.read_csv('newitems16.csv')
h
# Out:
#      Unnamed: 0                            product_name  \
# 0             0       Redmi K20 Pro (Flame Red, 128 GB)
# 1             1                Mi Mix 2 (Black, 128 GB)
# 2             2    Redmi K20 Pro (Carbon Black, 128 GB)
# 3             3         Mi A3 (More Than White, 128 GB)
# 4             4           Mi A3 (Not just Blue, 128 GB)
# 5             5     Redmi K20 Pro (Pearl White, 128 GB)
# 6             6    Redmi K20 Pro (Glacier Blue, 128 GB)
# 7             7       Redmi K20 Pro (Flame Red, 256 GB)
# 8             8         Redmi K20 (Carbon Black, 64 GB)
# 9             9                     Mi A2 (Red, 128 GB)
# 10           10            Mi A3 (Kind of Grey, 128 GB)
# 11           11         Redmi Note 6 Pro (Black, 64 GB)
# 12           12    Redmi K20 Pro (Carbon Black, 256 GB)
# 13           13        Redmi K20 (Glacier Blue, 128 GB)
# 14           14           Redmi K20 (Flame Red, 128 GB)
# 15           15          Redmi Note 5 Pro (Gold, 64 GB)
# ...

# %%
del h['Unnamed: 0']

# %%
h
# Out:
#                                product_name  \
# 0         Redmi K20 Pro (Flame Red, 128 GB)
# 1                  Mi Mix 2 (Black, 128 GB)
# 2      Redmi K20 Pro (Carbon Black, 128 GB)
# 3           Mi A3 (More Than White, 128 GB)
# 4             Mi A3 (Not just Blue, 128 GB)
# 5       Redmi K20 Pro (Pearl White, 128 GB)
# 6      Redmi K20 Pro (Glacier Blue, 128 GB)
# 7         Redmi K20 Pro (Flame Red, 256 GB)
# 8           Redmi K20 (Carbon Black, 64 GB)
# 9                       Mi A2 (Red, 128 GB)
# 10             Mi A3 (Kind of Grey, 128 GB)
# 11          Redmi Note 6 Pro (Black, 64 GB)
# 12     Redmi K20 Pro (Carbon Black, 256 GB)
# 13         Redmi K20 (Glacier Blue, 128 GB)
# 14            Redmi K20 (Flame Red, 128 GB)
# 15           Redmi Note 5 Pro (Gold, 64 GB)
# 16      Redmi K20 Pro (Pearl White, 256 GB)
# 17      Redmi Note 6 Pro (Rose Gold, 64 GB)
# 18         Redmi K20 (Carbon Black, 128 GB)
# 19      Redmi Note 6 Pro (Rose Gold, 64 GB)
# ...

# %%
x=h.iloc[:,[3,4,5,6,7,8,9]]
y=h.iloc[:,2]

# %%
x
# Out:
#      product_rating  Product_dimention in cm  Battery in mAh  Ram in GB  \
# 0               4.5                    16.23            4000          6
# 1               4.3                    15.21            3400          6
# 2               4.5                    16.23            4000          6
# 3               4.3                    15.44            4030          6
# 4               4.3                    15.44            4030          6
# 5               4.5                    16.23            4000          6
# 6               4.5                    16.23            4000          6
# 7               4.5                    16.23            4000          8
# 8               4.5                    16.23            4000          6
# 9               4.1                    15.21            3010          6
# 10              4.3                    15.44            4030          6
# 11              4.5                    15.90            4000          6
# ...

# %%
x = x.replace ('[^\d.]', '', regex=True).astype(float)

# %%
y
# Out:
# 0      26999
# 1      19999
# 2      26999
# 3      14999
# 4      17299
# 5      26999
# 6      26999
# 7      29999
# 8      21999
# 9      13999
# 10     17490
# 11     16295
# 12     29999
# 13     24999
# 14     24999
# 15     13999
# 16     29999
# 17     16374
# 18     24999
# 19     15490
# 20     24999
# 21     52590
# 22     14295
# 23     51990
# 24     13159
# 25     12999
# 26     13261
# 27     11199
# 28     10978
# 29      7399
#        ...
# 129     6499
# 130     8320
# 131     7990
# 132     7698
# 133     6890
# 134     7150
# 135     7250
# 136     7990
# 137     7150
# 138    12999
# 139    10595
# 140     8585
# 141     9150
# 142     5999
# 143     6499
# 144     6499
# 145     6999
# 146     5999
# 147     6999
# 148     6999
# 149     5590
# 150    12999
# 151     7499
# 152     7499
# 153    11349
# 154    13999
# 155     9999
# 156     9999
# 157    48500
# 158     9999
# Name: product_price, Length: 159, dtype: int64

# %%
corelation = h.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

# %%
corr = h.corr() #plot with actual values
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_0a004480_c2aa_11ea_8877_54e1ad6d9bdcrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0a004480_c2aa_11ea_8877_54e1ad6d9bdcrow0_col1 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_0a004480_c2aa_11ea_8877_54e1ad6d9bdcrow0_col2 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_0a004480_c2aa_11ea_8877_54e1ad6d9bdcrow0_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_0a004480_c2aa_11ea_8877_54e1ad6d9bdcrow0_col4 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_0a004480_c2aa_11ea_8877_54e1ad6d9bdcrow0_col5 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_0a004480_c2aa_11ea_8877_54e1ad6d9bdcrow0_col6 {
#             background-color:  #f1cdba;
#             color:  #000000;
# ...

# %%
product_price_corr = h.corr()['product_price']
product_price_corr
# Out:
# product_price              1.000000
# product_rating             0.502665
# Product_dimention in cm    0.459584
# Battery in mAh             0.300150
# Ram in GB                  0.771365
# Rom in GB                  0.762476
# Back_Camera in MP          0.769506
# Front_Camera in MP         0.409759
# Name: product_price, dtype: float64

# %%
##The above two plots, following the correlation matrix gives us a distinct ideative about how one 
##feature is dependent on the other and to what extent with values of dependency ranging between 0-1.
##The one towrds 1 has greator dependency while the one towards zero has lesser.

# %%
sns.relplot(x='product_price', y='Ram in GB',data=h)

# %%
sns.relplot(x='product_price', y='product_rating',data=h)

# %%
sns.relplot(x='product_price', y='Product_dimention in cm',data=h)

# %%
sns.relplot(x='product_price', y='Battery in mAh',data=h)

# %%
sns.relplot(x='product_price', y='Rom in GB',data=h)

# %%
sns.relplot(x='product_price', y='Back_Camera in MP',data=h)

# %%
sns.relplot(x='product_price', y='Front_Camera in MP',data=h)

# %%
##Scatter_plots gives us an idea of how x and y varies and quickly 
##helps to identifyy the outliners in the dataset.Moreover it even talks about it 
##being positively corelated, negatively corelated or no corelation at all.

# %%
h['product_processor'].unique()
# Out:
# array(['Qualcomm Snapdragon 855 Processor',
#        'Qualcomm Snapdragon 835 Octa Core 2.5 GHz Processor',
#        'Qualcomm Snapdragon 665 Processor',
#        'Qualcomm Snapdragon 730 Processor',
#        'Qualcomm Snapdragon 660 AIE Processor',
#        'Qualcomm Snapdragon 636 Processor',
#        'Qualcomm Spectra 480 ISP Processor',
#        '1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase',
#        'Snapdragon 439 octa core processor Processor',
#        'Qualcomm Snapdragon 675 Processor',
#        'Qualcomm\xc2\xae Snapdragon\xe2\x84\xa2 720G Processor',
#        'Qualcomm Snapdragon 625 Processor',
#        '2.0 GHz Mediatek P22 Octacore Processor',
#        'Qualcomm Snapdragon 632 Processor',
#        'Qualcomm Snapdragon 625 64-bit Octa Core 2GHz Processor',
#        'Qualcomm Snapdragon 439 Processor', '1 year',
#        'Qualcomm Snapdragon 425 Processor',
# ...

# %%
##i=h.loc[h['product_processor']=='Qualcomm Snapdragon 855 Processor']
##plt.plot(i['product_price'],np.zeros_like(i['product_price']),'o')
##plt.show()
##plt.xlabel('product_price')

# %%
##sns.FacetGrid(h,hue="Product_name" , size=5).map(plt.scatter,"product_price" "product_rating").add_legend()

# %%
sns.set()
cols = ['product_price','Ram in GB','Rom in GB']
sns.pairplot(h[cols], size = 2.5)
plt.show()
####'Product_dimention in cm','Battery in mAh','Ram in GB','Rom in GB','Back_Camera in MP','Front_Camera in MP'
# Out:
# C:\Users\Rajnandni Sharma\Anaconda2\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# AttributeErrorTraceback (most recent call last)
# <ipython-input-34-ab707deddf5b> in <module>()
#       2 cols = ['product_price','Ram in GB','Rom in GB']
#       3 sns.pairplot(h[cols], size = 2.5)
# ----> 4 plt.show()
#       5 ####'Product_dimention in cm','Battery in mAh','Ram in GB','Rom in GB','Back_Camera in MP','Front_Camera in MP'
#
# AttributeError: 'module' object has no attribute 'show'

# %%
sns.set()
cols = ['product_price','Product_dimention in cm','Battery in mAh']
sns.pairplot(h[cols], size = 2.5)
plt.show()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-35-bcddf2f2b5ca> in <module>()
#       2 cols = ['product_price','Product_dimention in cm','Battery in mAh']
#       3 sns.pairplot(h[cols], size = 2.5)
# ----> 4 plt.show()
#
# AttributeError: 'module' object has no attribute 'show'

# %%
##Pairplots are ways in which we can see our entire dataframed i
##in a condensed diagrammtic representation. It again gives us the idea about its corelation being positive, negative or no corelation at all. 
##In scatter plots, if we feel in pairplots that something is corelated and wish to see more
##distinctively, then scatter plots are handy.

# %%
sns.distplot(h['product_price'])

# %%
sns.distplot(h['Ram in GB'])

# %%
sns.distplot(h['Battery in mAh'])

# %%
sns.distplot(h['Back_Camera in MP'])

# %%
##Distplots represents data distribution of a variable for instance
##Back camera with its data distribution

# %%
sns.catplot(x='product_rating', kind='box', data=h)

# %%
sns.catplot(x='product_price', kind='box', data=h)

# %%
sns.catplot(x='Battery in mAh', kind='box', data=h)

# %%
##I used catplot for univariate analysis 
##Inorder to see like the range of the feature distinctively

# %%
##from sklearn.preprocessing import LabelEncoder,OneHotEncoder
##Labelencoder=LabelEncoder()
##x[:,1]=Labelencoder.fit_transform(x[:,1])
##onehotencoder=OneHotEncoder(categorical_features=[1])
##x=onehotencoder.fit_transform(x).toarray()## Tried  to make preprocessor the categorical variable, but impossible

# %%
h.plot(y='Back_Camera in MP')

# %%
h.plot(y='product_price')

# %%
h.plot(y='product_rating')

# %%
##I used these plots just to understand the frequency of rating and the high's and lows.

# %%
 box1= sns.boxplot(x='Battery in mAh' , y='product_rating' ,data=h)

# %%
 box1= sns.boxplot(x='Back_Camera in MP' , y='product_rating' ,data=h)

# %%
 box1= sns.boxplot(x='Ram in GB' , y='product_price' ,data=h)

# %%
box1= sns.boxplot(x='Rom in GB' , y='product_price' ,data=h)

# %%
box1= sns.boxplot(x='Ram in GB' , y='product_rating' ,data=h)

# %%
 ##Box plot show the distribution of numerical data and skewness 
##through displaying the data quartiles (or percentiles) and averages.
##1. upper quartile,
##2.Lower Quartile
##3.Min
##4.Max
##5.Median

# %%
sns.catplot(x = "Ram in GB", kind = "count", palette = "ch: 0.25", data = h)

# %%
sns.catplot(x = "Battery in mAh", kind = "count", palette = "ch: 0.25", data = h)

# %%
sns.catplot(x = "Rom in GB", kind = "count", palette = "ch: 0.25", data = h)

# %%
sns.catplot(x = "Back_Camera in MP", kind = "count", palette = "ch: 0.25", data = h)

# %%
sns.catplot(x = "Front_Camera in MP", kind = "count", palette = "ch: 0.25", data = h)

# %%
##I used them to get an idea of the count of phones 
##using 5mb camera and the camera in trend or the ram in trend. . 

##product_price              1.000000
##product_rating             0.502665
##Product_dimention in cm    0.459584
##Battery in mAh             0.300150
##Ram in GB                  0.771365
##Rom in GB                  0.762476
##Back_Camera in MP          0.769506
##Front_Camera in MP

# %%
h[['Ram in GB', 'product_processor']].groupby(['product_processor']).median().sort_values("Ram in GB", ascending = False).plot.bar()

# %%
h[['product_price', 'product_processor']].groupby(['product_processor']).median().sort_values("product_price", ascending = False).plot.bar()

# %%
h[['product_price', 'product_name']].groupby(['product_name']).median().sort_values("product_price", ascending = False).plot.bar(figsize=[20,10])
plt.show()

# %%
h[['product_price', 'Front_Camera in MP']].groupby(['Front_Camera in MP']).median().sort_values("product_price", ascending = False).plot.bar()

# %%
h[['product_price', 'Back_Camera in MP']].groupby(['Back_Camera in MP']).median().sort_values("product_price", ascending = False).plot

# %%
h[['product_rating', 'product_name']].groupby(['product_name']).median().sort_values("product_rating", ascending = False).plot.bar(figsize=[20,10])

# %%
##How price varies with the front cam, ram,rom battery and 
##all and the range of the price for the MI phones for all the models collectively,

# %%
##Regplot

# %%
sns.regplot(h['product_price'],h['Ram in GB'])

# %%
sns.regplot(h['product_price'],h['Front_Camera in MP'])

# %%
###Regplots are made.
###Scatterplot of two variables, x and y, and then fit the regression model y ~ x; 
###and plot the resulting regression line and a 95% confidence interval for that regression.
###
###It comes handy with very messy datasets and visualizations for it draws a reg ine.

# %%
##Outlier detection using z-score and IQR

# %%
##from scipy import stats
##zscore = np.abs(stats.zscore(h))
##print(zscore) doubt?? Why it didnt work

# %%
##threshold = 3
##print(np.where(zscore > 3))

# %%
##print(zscore[102][11])

# %%
h_iqr = h
Q1 = h_iqr.quantile(0.25)
Q3 = h_iqr.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# product_price              6000.00
# product_rating                0.20
# Product_dimention in cm       2.03
# Battery in mAh              880.00
# Ram in GB                     3.00
# Rom in GB                    32.00
# Back_Camera in MP            36.00
# Front_Camera in MP           15.00
# dtype: float64

# %%
print(h_iqr < (Q1 - 1.5 * IQR)) | (h_iqr > (Q3 + 1.5 * IQR))
# Out:
#      Back_Camera in MP  Battery in mAh  Front_Camera in MP  \
# 0                False           False               False
# 1                False           False               False
# 2                False           False               False
# 3                False           False               False
# 4                False           False               False
# 5                False           False               False
# 6                False           False               False
# 7                False           False               False
# 8                False           False               False
# 9                False           False               False
# 10               False           False               False
# 11               False           False               False
# 12               False           False               False
# 13               False           False               False
# 14               False           False               False
# ...

# %%
##h_clean = h
##h_clean = h_clean[(zscore < 3).all(axis=1)]

# %%
h.shape
# Out:
# (159, 10)

# %%
h_clean.shape
# Out:
# (159, 10)

# %%
h_iqr_clean = h_iqr[~((h_iqr < (Q1 - 1.5 * IQR)) | (h_iqr > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
h_iqr_clean.head()
# Out:
#                            product_name                  product_processor  \
# 8       Redmi K20 (Carbon Black, 64 GB)  Qualcomm Snapdragon 730 Processor
# 11      Redmi Note 6 Pro (Black, 64 GB)  Qualcomm Snapdragon 636 Processor
# 15       Redmi Note 5 Pro (Gold, 64 GB)  Qualcomm Snapdragon 636 Processor
# 17  Redmi Note 6 Pro (Rose Gold, 64 GB)  Qualcomm Snapdragon 636 Processor
# 19  Redmi Note 6 Pro (Rose Gold, 64 GB)  Qualcomm Snapdragon 636 Processor
#
#     product_price  product_rating  Product_dimention in cm  Battery in mAh  \
# 8           21999             4.5                    16.23            4000
# 11          16295             4.5                    15.90            4000
# 15          13999             4.5                    15.21            4000
# 17          16374             4.5                    15.90            4000
# 19          15490             4.5                    15.90            4000
#
#     Ram in GB  Rom in GB  Back_Camera in MP  Front_Camera in MP
# ...

# %%
inp_array = h_iqr_clean['product_price']
print ("Input array : ", inp_array)
# Out:
# ('Input array : ', 8      21999
# 11     16295
# 15     13999
# 17     16374
# 19     15490
# 22     14295
# 27     11199
# 28     10978
# 29      7399
# 30      7462
# 31      7499
# 35     12999
# 36     11540
# 38     15395
# 39      7450
# 40     12999
# 41     10999
# 43     12999
# 44      7499
# 45     12999
# 46     12999
# 47     12999
# 48     10999
# 49     11999
# 50      9999
# 51     10999
# 52     11999
# 53     10599
# 54      7999
# 55      8499
#        ...
# 128     5742
# 129     6499
# 130     8320
# 131     7990
# 132     7698
# 133     6890
# 134     7150
# 135     7250
# 136     7990
# 137     7150
# 138    12999
# 139    10595
# 140     8585
# 141     9150
# 142     5999
# 143     6499
# 144     6499
# 145     6999
# 146     5999
# 147     6999
# 148     6999
# 149     5590
# 150    12999
# 151     7499
# 152     7499
# 153    11349
# 154    13999
# 155     9999
# 156     9999
# 158     9999
# Name: product_price, Length: 125, dtype: int64)

# %%
#Applying log10 transformation with output values ranging from 0 to 2+
out_array = np.log10(inp_array) 
print ("Output array : ", out_array)
# Out:
# ('Output array : ', 8      4.342403
# 11     4.212054
# 15     4.146097
# 17     4.214155
# 19     4.190051
# 22     4.155184
# 27     4.049179
# 28     4.040523
# 29     3.869173
# 30     3.872855
# 31     3.875003
# 35     4.113910
# 36     4.062206
# 38     4.187380
# 39     3.872156
# 40     4.113910
# 41     4.041353
# 43     4.113910
# 44     3.875003
# 45     4.113910
# 46     4.113910
# 47     4.113910
# 48     4.041353
# 49     4.079145
# 50     3.999957
# 51     4.041353
# 52     4.079145
# 53     4.025265
# 54     3.903036
# 55     3.929368
#          ...
# 128    3.759063
# 129    3.812847
# 130    3.920123
# 131    3.902547
# 132    3.886378
# 133    3.838219
# 134    3.854306
# 135    3.860338
# 136    3.902547
# 137    3.854306
# 138    4.113910
# 139    4.025101
# 140    3.933740
# 141    3.961421
# 142    3.778079
# 143    3.812847
# 144    3.812847
# 145    3.845036
# 146    3.778079
# 147    3.845036
# 148    3.845036
# 149    3.747412
# 150    4.113910
# ...

# %%
#Boxplot showing No outliers with all of them treated by doing log10 transformation.
##out_array.catplot()
##plt.show()(This didnt work)
##it shud work

# %%
#Right Skewed data transformed to Fairly or close to Normal Distribution using Log10 transformations
sns.distplot(out_array)

# %%
#log10 values as shown below.
original_val = (10**out_array) 
print ("Original Values : ", original_val)
# Out:
# ('Original Values : ', 8      21999.0
# 11     16295.0
# 15     13999.0
# 17     16374.0
# 19     15490.0
# 22     14295.0
# 27     11199.0
# 28     10978.0
# 29      7399.0
# 30      7462.0
# 31      7499.0
# 35     12999.0
# 36     11540.0
# 38     15395.0
# 39      7450.0
# 40     12999.0
# 41     10999.0
# 43     12999.0
# 44      7499.0
# 45     12999.0
# 46     12999.0
# 47     12999.0
# 48     10999.0
# 49     11999.0
# 50      9999.0
# 51     10999.0
# 52     11999.0
# 53     10599.0
# 54      7999.0
# 55      8499.0
#         ...
# 128     5742.0
# 129     6499.0
# 130     8320.0
# 131     7990.0
# 132     7698.0
# 133     6890.0
# 134     7150.0
# 135     7250.0
# 136     7990.0
# 137     7150.0
# 138    12999.0
# 139    10595.0
# 140     8585.0
# 141     9150.0
# 142     5999.0
# 143     6499.0
# 144     6499.0
# 145     6999.0
# 146     5999.0
# 147     6999.0
# 148     6999.0
# 149     5590.0
# 150    12999.0
# 151     7499.0
# 152     7499.0
# 153    11349.0
# ...

# %%
#### Square Root Transformation

# %%
h_iqr_clean.boxplot(column='Battery in mAh')
plt.show()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-101-4144836a2961> in <module>()
#       1 h_iqr_clean.boxplot(column='Battery in mAh')
# ----> 2 plt.show()
#
# AttributeError: 'module' object has no attribute 'show'

# %%
inp_array2 = h_iqr_clean['Battery in mAh'] 
print ("Input array : ", inp_array2)
# Out:
# ('Input array : ', 8      4000
# 11     4000
# 15     4000
# 17     4000
# 19     4000
# 22     3010
# 27     4000
# 28     4000
# 29     5000
# 30     5000
# 31     5000
# 35     5020
# 36     4000
# 38     4000
# 39     5000
# 40     4000
# 41     4000
# 43     4000
# 44     5000
# 45     5020
# 46     5020
# 47     4000
# 48     4000
# 49     4000
# 50     4000
# 51     4000
# 52     4000
# 53     3010
# 54     3080
# 55     3000
#        ...
# 128    3000
# 129    4000
# 130    3300
# 131    3300
# 132    3300
# 133    3300
# 134    3300
# 135    3300
# 136    3300
# 137    3300
# 138    4100
# 139    4000
# 140    3300
# 141    4000
# 142    2000
# 143    5000
# 144    3000
# 145    3000
# 146    3000
# 147    3000
# 148    3000
# 149    3000
# 150    3030
# 151    4100
# 152    4100
# 153    4000
# 154    4100
# 155    5000
# 156    5000
# 158    5000
# Name: Battery in mAh, Length: 125, dtype: int64)

# %%
 out_array2 = np.sqrt(inp_array2) 
print ("Output array : ", out_array2)
# Out:
# ('Output array : ', 8      63.245553
# 11     63.245553
# 15     63.245553
# 17     63.245553
# 19     63.245553
# 22     54.863467
# 27     63.245553
# 28     63.245553
# 29     70.710678
# 30     70.710678
# 31     70.710678
# 35     70.851958
# 36     63.245553
# 38     63.245553
# 39     70.710678
# 40     63.245553
# 41     63.245553
# 43     63.245553
# 44     70.710678
# 45     70.851958
# 46     70.851958
# 47     63.245553
# 48     63.245553
# 49     63.245553
# 50     63.245553
# 51     63.245553
# 52     63.245553
# 53     54.863467
# 54     55.497748
# 55     54.772256
#          ...
# 128    54.772256
# 129    63.245553
# 130    57.445626
# 131    57.445626
# 132    57.445626
# 133    57.445626
# 134    57.445626
# 135    57.445626
# 136    57.445626
# 137    57.445626
# 138    64.031242
# 139    63.245553
# 140    57.445626
# 141    63.245553
# 142    44.721360
# 143    70.710678
# 144    54.772256
# 145    54.772256
# 146    54.772256
# 147    54.772256
# ...

# %%
##.boxplot(column='Battery in mAh')
##plt.show()

# %%
sns.distplot(out_array2)

# %%
##Ram in GB	Rom in GB	Back_Camera in MP	Front_Camera in MP

# %%
def clean_dataset(x):
    assert isinstance(x, pd.DataFrame), "h needs to be a pd.DataFrame"
    x.dropna(inplace=True)
    indices_to_keep = ~x.isin([np.nan, np.inf, -np.inf]).any(1)
    return x[indices_to_keep].astype(np.float64)

# %%
##x_test = x_test.fillna(x_train.mean())

# %%
clean_dataset(x)
# Out:
#      product_rating  Product_dimention in cm  Battery in mAh  Ram in GB  \
# 0               4.5                    16.23          4000.0        6.0
# 1               4.3                    15.21          3400.0        6.0
# 2               4.5                    16.23          4000.0        6.0
# 3               4.3                    15.44          4030.0        6.0
# 4               4.3                    15.44          4030.0        6.0
# 5               4.5                    16.23          4000.0        6.0
# 6               4.5                    16.23          4000.0        6.0
# 7               4.5                    16.23          4000.0        8.0
# 8               4.5                    16.23          4000.0        6.0
# 9               4.1                    15.21          3010.0        6.0
# 10              4.3                    15.44          4030.0        6.0
# 11              4.5                    15.90          4000.0        6.0
# ...

# %%
h.dropna(inplace=True)

# %%
h
# Out:
#                                product_name  \
# 0         Redmi K20 Pro (Flame Red, 128 GB)
# 1                  Mi Mix 2 (Black, 128 GB)
# 2      Redmi K20 Pro (Carbon Black, 128 GB)
# 3           Mi A3 (More Than White, 128 GB)
# 4             Mi A3 (Not just Blue, 128 GB)
# 5       Redmi K20 Pro (Pearl White, 128 GB)
# 6      Redmi K20 Pro (Glacier Blue, 128 GB)
# 7         Redmi K20 Pro (Flame Red, 256 GB)
# 8           Redmi K20 (Carbon Black, 64 GB)
# 9                       Mi A2 (Red, 128 GB)
# 10             Mi A3 (Kind of Grey, 128 GB)
# 11          Redmi Note 6 Pro (Black, 64 GB)
# 12     Redmi K20 Pro (Carbon Black, 256 GB)
# 13         Redmi K20 (Glacier Blue, 128 GB)
# 14            Redmi K20 (Flame Red, 128 GB)
# 15           Redmi Note 5 Pro (Gold, 64 GB)
# 16      Redmi K20 Pro (Pearl White, 256 GB)
# 17      Redmi Note 6 Pro (Rose Gold, 64 GB)
# 18         Redmi K20 (Carbon Black, 128 GB)
# 19      Redmi Note 6 Pro (Rose Gold, 64 GB)
# ...

# %%
h.shape
# Out:
# (152, 10)

# %%
h[h.replace([np.inf, -np.inf], np.nan).notnull().all(axis=1)]
# Out:
#                                product_name  \
# 0         Redmi K20 Pro (Flame Red, 128 GB)
# 1                  Mi Mix 2 (Black, 128 GB)
# 2      Redmi K20 Pro (Carbon Black, 128 GB)
# 3           Mi A3 (More Than White, 128 GB)
# 4             Mi A3 (Not just Blue, 128 GB)
# 5       Redmi K20 Pro (Pearl White, 128 GB)
# 6      Redmi K20 Pro (Glacier Blue, 128 GB)
# 7         Redmi K20 Pro (Flame Red, 256 GB)
# 8           Redmi K20 (Carbon Black, 64 GB)
# 9                       Mi A2 (Red, 128 GB)
# 10             Mi A3 (Kind of Grey, 128 GB)
# 11          Redmi Note 6 Pro (Black, 64 GB)
# 12     Redmi K20 Pro (Carbon Black, 256 GB)
# 13         Redmi K20 (Glacier Blue, 128 GB)
# 14            Redmi K20 (Flame Red, 128 GB)
# 15           Redmi Note 5 Pro (Gold, 64 GB)
# 16      Redmi K20 Pro (Pearl White, 256 GB)
# 17      Redmi Note 6 Pro (Rose Gold, 64 GB)
# 18         Redmi K20 (Carbon Black, 128 GB)
# 19      Redmi Note 6 Pro (Rose Gold, 64 GB)
# ...

# %%
h
# Out:
#                                product_name  \
# 0         Redmi K20 Pro (Flame Red, 128 GB)
# 1                  Mi Mix 2 (Black, 128 GB)
# 2      Redmi K20 Pro (Carbon Black, 128 GB)
# 3           Mi A3 (More Than White, 128 GB)
# 4             Mi A3 (Not just Blue, 128 GB)
# 5       Redmi K20 Pro (Pearl White, 128 GB)
# 6      Redmi K20 Pro (Glacier Blue, 128 GB)
# 7         Redmi K20 Pro (Flame Red, 256 GB)
# 8           Redmi K20 (Carbon Black, 64 GB)
# 9                       Mi A2 (Red, 128 GB)
# 10             Mi A3 (Kind of Grey, 128 GB)
# 11          Redmi Note 6 Pro (Black, 64 GB)
# 12     Redmi K20 Pro (Carbon Black, 256 GB)
# 13         Redmi K20 (Glacier Blue, 128 GB)
# 14            Redmi K20 (Flame Red, 128 GB)
# 15           Redmi Note 5 Pro (Gold, 64 GB)
# 16      Redmi K20 Pro (Pearl White, 256 GB)
# 17      Redmi Note 6 Pro (Rose Gold, 64 GB)
# 18         Redmi K20 (Carbon Black, 128 GB)
# 19      Redmi Note 6 Pro (Rose Gold, 64 GB)
# ...

# %%
x.shape
# Out:
# (152, 7)

# %%
y.shape
# Out:
# (158L,)

# %%
##y=y.drop(index=[152])
y.shape
# Out:
# (158L,)

# %%
y.tail(10)
# Out:
# 148     6999
# 149     5590
# 150    12999
# 151     7499
# 153    11349
# 154    13999
# 155     9999
# 156     9999
# 157    48500
# 158     9999
# Name: product_price, dtype: int64

# %%
y=y.drop(index=[154])
y
# Out:
# 0      26999
# 1      19999
# 2      26999
# 3      14999
# 4      17299
# 5      26999
# 6      26999
# 7      29999
# 8      21999
# 9      13999
# 10     17490
# 11     16295
# 12     29999
# 13     24999
# 14     24999
# 15     13999
# 16     29999
# 17     16374
# 18     24999
# 19     15490
# 20     24999
# 21     52590
# 22     14295
# 23     51990
# 24     13159
# 25     12999
# 26     13261
# 27     11199
# 28     10978
# 29      7399
#        ...
# 127     5976
# 128     5742
# 129     6499
# 130     8320
# 131     7990
# 132     7698
# 133     6890
# 134     7150
# 135     7250
# 136     7990
# 137     7150
# 138    12999
# 139    10595
# 140     8585
# 141     9150
# 142     5999
# 143     6499
# 144     6499
# 145     6999
# 146     5999
# 147     6999
# 148     6999
# 149     5590
# 150    12999
# 151     7499
# 153    11349
# 155     9999
# 156     9999
# 157    48500
# 158     9999
# Name: product_price, Length: 157, dtype: int64

# %%
##y=y.drop(index=[155])

# %%
##y=y.drop(index=[156])

# %%
##y=y.drop(index=[157])

# %%
##y=y.drop(index=[158])

# %%
##y=y.drop(index=[153])

# %%
y
# Out:
# 0      26999
# 1      19999
# 2      26999
# 3      14999
# 4      17299
# 5      26999
# 6      26999
# 7      29999
# 8      21999
# 9      13999
# 10     17490
# 11     16295
# 12     29999
# 13     24999
# 14     24999
# 15     13999
# 16     29999
# 17     16374
# 18     24999
# 19     15490
# 20     24999
# 21     52590
# 22     14295
# 23     51990
# 24     13159
# 25     12999
# 26     13261
# 27     11199
# 28     10978
# 29      7399
#        ...
# 122    16999
# 123    10599
# 124    10290
# 125     7999
# 126    14999
# 127     5976
# 128     5742
# 129     6499
# 130     8320
# 131     7990
# 132     7698
# 133     6890
# 134     7150
# 135     7250
# 136     7990
# 137     7150
# 138    12999
# 139    10595
# 140     8585
# 141     9150
# 142     5999
# 143     6499
# 144     6499
# 145     6999
# 146     5999
# 147     6999
# 148     6999
# 149     5590
# 150    12999
# 151     7499
# Name: product_price, Length: 152, dtype: int64

# %%
x.shape
# Out:
# (152, 7)

# %%
y.shape
# Out:
# (152L,)

# %%
##Feature Importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [0.21832577 0.15791721 0.17312438 0.1225724  0.13696079 0.09397244
#  0.09712701]

# %%
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
classifier=LinearRegression()
classifier.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred=classifier.predict(x_test)
y_pred
# Out:
# array([ 9440.57831998, 12071.30227384, 11498.64986088, 20388.83215651,
#         8524.85043812, 15949.36516567,  8803.98208649, 27682.74511625,
#         6116.47201365, 14382.51457958, 15388.79270499,  9386.60639734,
#        13812.69634711, 20388.83215651,  8135.94987008, 13812.69634711,
#         8135.94987008, 11482.78813714,  5650.31605144, 24115.28860323,
#        12782.62200343, 10800.86274954,  6772.34817691, 12389.7651858 ,
#        12389.7651858 ,  4685.06323162, 27682.74511625,  8694.5001455 ,
#        12071.30227384, 13416.29098469, 18565.22299505])

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

# %%
score
# Out:
# 0.387768839251149

# %%
from matplotlib import pyplot as plt 
import numpy as np 
  
  
# Creating dataset 
product_rating = ['4.3', '4.4', '4.5', '4.6','4.7','4.8'] 
  
data = [4,12,26,27,25,6] 
  
# Creating plot 
fig = plt.figure(figsize =(7, 7)) 
plt.pie(data, labels = product_rating) 
  
# show plot 
plt.show()
